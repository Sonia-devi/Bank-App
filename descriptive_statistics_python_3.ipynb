# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonia-devi/Bank-App/blob/main/descriptive_statistics_python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import scipy.stats as stats
from matplotlib import pyplot as plt
import seaborn as sns
from pandas import Series, DataFrame

# %%
#Load the Dataset
df = pd.read_excel(r"/content/transformation of dataset 1 1.xlsx")

# %%
df.head()
# Out:
#    Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 0          1           1       0             1   102.0    1.84  30.127599
# 1          3           1       0             1    82.7    1.78  26.101502
# 2          1           1       0             1    80.0    2.00  20.000000
# 3          1           1       0             1    80.0    1.75  26.122449
# 4          0           1       0             1    89.0    1.78  28.089888
#
#    Aviation Sector  Flight Hours  Flight Type  ...  Breathing Difficulties  \
# 0              1.0        5000.0          1.0  ...                       0
# 1              1.0        4200.0          1.0  ...                       0
# 2              1.0        6100.0          4.0  ...                       0
# 3              1.0        6000.0          4.0  ...                       0
# 4              1.0        1000.0          2.0  ...                       1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age Group                          295 non-null    int64
#  1   Handedness                         295 non-null    int64
#  2   Gender                             295 non-null    int64
#  3   Job Function                       295 non-null    int64
#  4   Weight                             291 non-null    float64
#  5   Height                             289 non-null    float64
#  6   BMI                                287 non-null    float64
#  7   Aviation Sector                    291 non-null    float64
#  8   Flight Hours                       166 non-null    float64
#  9   Flight Type                        205 non-null    float64
#  10  Bed Time                           294 non-null    float64
# ...

# %%
df.tail()
# Out:
#      Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 290          0           1       0             5   105.0    1.88  29.708013
# 291          1           1       0             3    60.0    1.66  21.773842
# 292          2           0       0             2   100.0    1.90  27.700831
# 293          2           1       1             3    72.0    1.67  25.816630
# 294          3           1       0             3    90.0    1.78  28.405504
#
#      Aviation Sector  Flight Hours  Flight Type  ...  Breathing Difficulties  \
# 290              4.0           NaN          NaN  ...                       3
# 291              4.0           NaN          NaN  ...                       0
# 292              4.0           NaN          NaN  ...                       0
# 293              4.0           NaN          NaN  ...                       0
# 294              4.0           NaN          NaN  ...                       0
#
# ...

# %%
df.shape
# Out:
# (295, 28)

# %%
#finding the duplicate values
initial_rows = df.shape[0]
df.drop_duplicates(inplace=True)
final_rows = df.shape[0]

if initial_rows == final_rows:
  print("No Duplicate Values Found.")
else:
  print("Duplicate Values Found and Dropped")

#Handle missing values, if any
if df.isnull().sum().sum() == 0:
  print("No Missing Values Found.")
else:
  print("Missing Values Found and Handled.")
# Out:
# No Duplicate Values Found.
# Missing Values Found and Handled.

# %%
#Due to missing values (NaN), I performed "Imputation" which enabled me to fill in missing values with estimated values and I did this due to the size of my dataset, because if I had dropped the columns with Null (NaN) values it would reduce my dataset drastically.

df_2= df.fillna(df.mean())

df_2
# Out:
# <ipython-input-68-980c1f43c6b9>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_2= df.fillna(df.mean())
#      Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 0            1           1       0             1   102.0    1.84  30.127599
# 1            3           1       0             1    82.7    1.78  26.101502
# 2            1           1       0             1    80.0    2.00  20.000000
# 3            1           1       0             1    80.0    1.75  26.122449
# 4            0           1       0             1    89.0    1.78  28.089888
# ..         ...         ...     ...           ...     ...     ...        ...
# 290          0           1       0             5   105.0    1.88  29.708013
# ...

# %%
df_2.tail()
# Out:
#      Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 290          0           1       0             5   105.0    1.88  29.708013
# 291          1           1       0             3    60.0    1.66  21.773842
# 292          2           0       0             2   100.0    1.90  27.700831
# 293          2           1       1             3    72.0    1.67  25.816630
# 294          3           1       0             3    90.0    1.78  28.405504
#
#      Aviation Sector  Flight Hours  Flight Type  ...  Breathing Difficulties  \
# 290              4.0           NaN          NaN  ...                       3
# 291              4.0           NaN          NaN  ...                       0
# 292              4.0           NaN          NaN  ...                       0
# 293              4.0           NaN          NaN  ...                       0
# 294              4.0           NaN          NaN  ...                       0
#
# ...

# %%
df_2.describe() #(calculating some statistical data like percentile, mean and std of the numerical values )
# Out:
#         Age Group  Handedness      Gender  Job Function      Weight  \
# count  295.000000  295.000000  295.000000    295.000000  295.000000
# mean     1.884746    0.894915    0.233898      2.423729   81.473952
# std      1.121954    0.394444    0.431975      1.812686   16.806353
# min      0.000000    0.000000    0.000000      1.000000   52.000000
# 25%      1.000000    1.000000    0.000000      1.000000   71.000000
# 50%      2.000000    1.000000    0.000000      1.000000   80.000000
# 75%      3.000000    1.000000    0.000000      4.000000   90.000000
# max      5.000000    2.000000    2.000000      6.000000  190.000000
#
#            Height         BMI  Aviation Sector  Flight Hours  Flight Type  \
# count  295.000000  295.000000       295.000000    295.000000   295.000000
# mean     1.763744   26.151228         1.439863   7755.638554     2.263415
# std      0.088335    4.826239         0.811687   3961.099000     1.039649
# ...

# %%
df_2.sample(frac=0.5) # (get a subset of random rows or columns)
# Out:
#      Age Group  Handedness  Gender  Job Function  Weight  Height        BMI  \
# 291          1           1       0             3    60.0    1.66  21.773842
# 124          2           0       0             1    80.0    1.78  25.249337
# 93           3           1       0             1   110.0    1.78  34.717839
# 99           2           1       0             1    60.0    1.72  20.281233
# 77           2           1       0             1    85.0    1.80  26.234568
# ..         ...         ...     ...           ...     ...     ...        ...
# 119          1           1       0             1    80.0    1.80  24.691358
# 46           3           1       0             1    82.5    1.72  27.886696
# 70           1           1       0             1    85.0    1.80  26.234568
# 120          1           1       0             1    52.0    1.72  17.577069
# 67           3           1       0             1    86.0    1.73  28.734672
#
# ...

# %%
sample_data = df_2.sample(frac=0.05)

# %%
sample_data.describe()
# Out:
#        Age Group  Handedness     Gender  Job Function     Weight     Height  \
# count  15.000000   15.000000  15.000000     15.000000  15.000000  15.000000
# mean    1.866667    0.933333   0.200000      1.866667  78.566667   1.758000
# std     1.245946    0.457738   0.414039      1.505545   9.533525   0.065922
# min     0.000000    0.000000   0.000000      1.000000  62.000000   1.680000
# 25%     1.000000    1.000000   0.000000      1.000000  73.000000   1.700000
# 50%     2.000000    1.000000   0.000000      1.000000  77.000000   1.750000
# 75%     3.000000    1.000000   0.000000      2.500000  87.500000   1.800000
# max     4.000000    2.000000   1.000000      6.000000  92.000000   1.880000
#
#              BMI  Aviation Sector  Flight Hours  Flight Type  ...  \
# count  15.000000        15.000000     15.000000    15.000000  ...
# mean   25.379997         1.066667   8618.546185     2.484228  ...
# std     2.359126         0.258199   5301.950934     1.181774  ...
# ...

# %%
# Calculate descriptive statistics for Age Group
Age_Group_stats = df_2["Age Group"].describe()
print("Age Group descriptive statistics:", Age_Group_stats)
# Out:
# Age Group descriptive statistics: count    295.000000
# mean       1.884746
# std        1.121954
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000
# Name: Age Group, dtype: float64

# %%
# Calculate descriptive statistics for Gender
Gender_stats = df_2["Gender"].describe()
print("Gender descriptive statistics:", Gender_stats)
# Out:
# Gender descriptive statistics: count    295.000000
# mean       0.233898
# std        0.431975
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000
# Name: Gender, dtype: float64

# %%
# Calculate descriptive statistics for Job Function
Job_Function_stats = df_2["Job Function"].describe()
print("Job Function descriptive statistics:", Job_Function_stats)
# Out:
# Job Function descriptive statistics: count    295.000000
# mean       2.423729
# std        1.812686
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        4.000000
# max        6.000000
# Name: Job Function, dtype: float64

# %%
# Calculate descriptive statistics for BMI
BMI_stats = df_2["BMI"].describe()
print("BMI descriptive statistics:",BMI_stats)
# Out:
# BMI descriptive statistics: count    295.000000
# mean      26.151228
# std        4.826239
# min       17.577069
# 25%       23.315049
# 50%       25.816630
# 75%       27.755102
# max       65.743945
# Name: BMI, dtype: float64

# %%
# Calculate descriptive statistics for Aviation Sector
Aviation_Sector_stats = df_2["Aviation Sector"].describe()
print("Aviation Sector descriptive statistics:", Aviation_Sector_stats)
# Out:
# Aviation Sector descriptive statistics: count    295.000000
# mean       1.439863
# std        0.811687
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000
# Name: Aviation Sector, dtype: float64

# %%
# Calculate descriptive statistics for Flight Hours
Flight_Hours_stats = df_2["Flight Hours"].describe()
print("Flight Hours descriptive statistics:", Flight_Hours_stats)
# Out:
# Flight Hours descriptive statistics: count      295.000000
# mean      7755.638554
# std       3961.099000
# min         56.000000
# 25%       6050.000000
# 50%       7755.638554
# 75%       8000.000000
# max      22000.000000
# Name: Flight Hours, dtype: float64

# %%
# Calculate descriptive statistics for Flight Type
Flight_Type_stats = df_2["Flight Type"].describe()
print("Flight Type descriptive statistics:", Flight_Type_stats)
# Out:
# Flight Type descriptive statistics: count    295.000000
# mean       2.263415
# std        1.039649
# min        1.000000
# 25%        2.000000
# 50%        2.263415
# 75%        2.263415
# max        6.000000
# Name: Flight Type, dtype: float64

# %%
# Calculate descriptive statistics for Bed Time
Bed_Time_stats = df_2["Bed Time"].describe()
print("Bed Time descriptive statistics:", Bed_Time_stats)
# Out:
# Bed Time descriptive statistics: count    295.000000
# mean       2.510204
# std        1.298180
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        8.000000
# Name: Bed Time, dtype: float64

# %% [markdown]
# #visualisation of dataset

# %%
#histogram plot
df_2['Age Group'].plot(kind='hist', bins=10, figsize=(5,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
fig,axes = plt.subplots(nrows=1,ncols = 3,figsize=(20,5))

sns.lineplot(ax=axes[0],x='Sleep Quality',y='BMI',data = df_2);
sns.lineplot(ax=axes[1],x='Sleep Quality',y='Age Group',data = df_2);
sns.lineplot(ax=axes[2],x='Sleep Quality',y='Bed Time',data = df_2);


axes[0].title.set_text('Relationship between Sleep Quality and BMI')
axes[1].title.set_text('Relationship between Sleep Quality and Age')
axes[2].title.set_text('Relationship between Sleep Quality and Bed Time')
